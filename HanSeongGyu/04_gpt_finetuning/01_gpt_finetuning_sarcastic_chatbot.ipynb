# %% [markdown]
# # GPT Fine-tuning
#
# https://platform.openai.com/docs/guides/fine-tuning

# %% [markdown]
# ## 데이터 준비
# - jsonl 형식
# - messages 기준으로 작성해둘것
#     - system, user, assistant - role 작성
# - file 업로드 후 file-id 복사

# %% [markdown]
# ## Fine-tuning 학습
# - finetuning 학습 job 생성

# %% [markdown]
# ## Fine-tuned 모델 추론

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# %%
from openai import OpenAI

model = 'ft:gpt-4o-2024-08-06:seong9s:sarcastic-chatbot:BmsGwswo'

client = OpenAI(api_key=OPENAI_API_KEY)

def sarcastic_chatbot(prompt, temperature = 0.7 ):
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": "너는 사실을 말하는 챗봇이지만, 빈정대거나 비꼬는 말투로 응답하는 챗봇이다."},
            {'role': 'user' , 'content' : prompt}
        ],
        temperature = temperature
    )
    return response.choices[0].message.content

# %%
sarcastic_chatbot(' 도시락 싸온 걸 먹을까, 짜장면& 탕수육을 사먹을까')
# Out:
# '짜장면&탕수육 가라. 도시락보단 그게 낫겠지.'
