# %% [markdown]
# # GPT Fine-tuning
# https://platform.openai.com/docs/guides/fine-tuning

# %% [markdown]
# ## 데이터 준비
# - jsonl 형식
# - messages 기준으로 작성할 것
#  - system, user, assistant 같은 role들을 부여해야 함
# - 파일 업로드 후 file-id 복사

# %% [markdown]
# ## Fine-tuning 학습
# - finetuning 학습 job 생성
