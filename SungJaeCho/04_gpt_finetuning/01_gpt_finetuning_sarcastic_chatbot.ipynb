# %% [markdown]
# # GPT Fine-tuning
#
# https://platform.openai.com/docs/guides/fine-tuning

# %% [markdown]
# ## 데이터 준비
# - jsonl형식
# - messages 기준으로 작성해둘것.
#   -system, user, assistant
# - 파일 업로드후 file-id 복사

# %% [markdown]
# ## Fine-tuning 학습
# - finetuning 학습 job 생성

# %% [markdown]
# ## Fine-tuned 모델 추론

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# %%
from openai import OpenAI

model = 'ft:gpt-4o-2024-08-06:whtjdwo9267:sarcastic-chatbot:BmsIo3XL'

client =OpenAI(api_key=OPENAI_API_KEY)

def sarcastic_chatbot(prompt, temperature=1):
  response = client.chat.completions.create(
    model=model,
    messages = [
        {"role": "system", "content": "너는 사실을 말하는 챗봇이야"},
        {"role": "user", "content": prompt}
    ],
    temperature=temperature
  )
  return response.choices[0].message.content

# %%
sarcastic_chatbot('아이폰이랑 갤럭시랑 뭐가 더 좋아')
# Out:
# '둘 다 장점이 있어. 아이폰은 iOS의 부드러운 사용자 경험과 업데이트 지원이 강점이고, 갤럭시는 다양한 모델과 커스터마이즈 가능한 기능이 매력적이야. 네 필요에 맞춰 선택하면 돼.'
