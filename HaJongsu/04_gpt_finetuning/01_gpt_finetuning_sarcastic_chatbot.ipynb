# %% [markdown]
# # GPT Fine-tuning

# %% [markdown]
# ## 데이터 준비
# - jsonl 형식
# - messages 기준으로 작성해둘것
#     - system, user, assitant
# - 파일 업로드 후 file-id 복사

# %% [markdown]
# ## Fine-tuning 학습
# - fine-tuning 학습 job 생성
