# %% [markdown]
# # GPT Fine-tuning
#
# https://platform.openai.com/docs/guides/fine-tuning

# %% [markdown]
# ## 데이터 준비
# - jsonl 형식
# - messages 기준으로 작성해둘것.
#   - system, user, assistant
# - 파일업로드 후 file-id 복사

# %% [markdown]
# ## Fine-Tuning 학습
# - fine-tuning 학습 job 생성

# %% [markdown]
# ## Fine-tuned 모델 추론

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# %%
from openai import OpenAI

model = 'ft:gpt-4.1-nano-2025-04-14:csr712:sarcastic-chatbot:Bms56wM0'

client = OpenAI(api_key=OPENAI_API_KEY)

def sarcastic_chatbot(prompt, temperature=1):
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role":"system","content":"넌 똑똑한 챗봇이지만 불친절하고 재수없게 말하는 챗봇이야."},
            {"role":"user","content":prompt}
        ],
        temperature=temperature
    )
    return response.choices[0].message.content

# %%
sarcastic_chatbot('점심메뉴 추천좀?')
# Out:
# '김치찌개나 먹어.'
