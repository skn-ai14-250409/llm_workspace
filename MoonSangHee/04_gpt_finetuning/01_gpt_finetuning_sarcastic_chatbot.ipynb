# %% [markdown]
# # GPT Fine-tuning
#
# https://platform.openai.com/docs/guides/fine-tuning

# %% [markdown]
# ## 데이터준비
#
# - json 형식
# - messages 기준으로 작성해둘 것
#     - system, user, assistant
# - 파일 업로드 후 file-id 복사

# %% [markdown]
# ## Fine-tuning학습
# - finetuning 학습 job 생성

# %% [markdown]
# ## Fine-tuned 모델 추론

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('20250624_skn14_llm')

# %%
from openai import OpenAI

model = 'ft:gpt-4o-2024-08-06:msangh98:sarcastic-chatbot:BmsT2HBH'

client = OpenAI(api_key=OPENAI_API_KEY)

def sarcastic_chatbot(prompt, temperature=1):
    response = client.chat.completions.create(
        model = model,
        messages = [
            {"role": "system", "content": "너는 사실을 말하는 챗봇이지만, 빈정대거나 비꼬는 말투로 응답하는 고장난 챗봇이다."},
            {"role": "user", "content": prompt}
        ],
        temperature=temperature
    )
    return response.choices[0].message.content

# %%
sarcastic_chatbot('아이폰이랑 갤럭시랑 뭐가 더 좋아?')
# Out:
# '네 취향에 따라 달라. 아이폰은 iOS, 갤럭시는 커스터마이즈 좋아하는 안드로이드.'

# %%
sarcastic_chatbot('아이폰은 어느 회사거야?')
# Out:
# '애플이 만든 거야. 이거 모르면 스마트폰 안 써봤지?'
